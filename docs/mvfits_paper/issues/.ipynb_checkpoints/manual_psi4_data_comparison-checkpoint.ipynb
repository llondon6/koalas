# %% [markdown]
# # Manually load and inspect Ylm_depict data

# %%
# Low-level import 
from numpy import array,loadtxt,linspace,zeros,exp,ones,unwrap,angle,pi

# Setup ipython environment
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Import useful things from kerr
from kerr.formula.ksm2_cw import CW as cwfit
from kerr.formula.ksm2_sc import SC as scfit
from kerr.pttools import leaver_workfunction as lvrwork
from kerr import leaver,rgb
from kerr.models import mmrdns 

#
from nrutils import scsearch,gwylm,gwf

# Setup plotting backend
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 0.8
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.labelsize'] = 20
from matplotlib.pyplot import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
T0 = 10
ll,mm = 4,3
q = 2.8
data_file_string = '/Users/book/GARREG/Spectroscopy/Ylm_Depictions/NonPrecessing/MULTI_DATA_6/T0_%i_nmax2_Mmin97ll_Mmin_r75_qref1.50__p1_17-Mar-2014gnx_/Data_Sets/HRq-series/D9_q%1.1f_a0.0_m160/DEPICTION_INFO::NODD_INPUT_ll%i_mm%i_r75.asc'%(T0,q,ll,mm)
data = loadtxt(data_file_string)

# %%
# Collect raw fit data for later convenience
rfdata = {}
for k,row in enumerate(data):
    #
    ll,mm,q,m1,m2,x1,x2,jf,Mf,qid,rew,imw,rewfit,imwfit,reA,imA,reAmean,imAmean,minA,maxA,T1,dT,match,rmse,reB,imB,reBmean,imBmean,minB,maxB = row
    ll,mm = int(ll),int(mm)
    A = reA+1j*imA
    cw = rew + 1j*imw
    try:
        l,m,n,p = mmrdns.calc_z(qid)
    except:
        l,m,n,p,l2,m2,n2,p2 = mmrdns.calc_z(qid)
    rfdata[(l,m,n,p)] = {}
    rfdata[(l,m,n,p)]['ll'],rfdata[(l,m,n,p)]['mm'],rfdata[(l,m,n,p)]['A'],rfdata[(l,m,n,p)]['cw'] = ll,mm,A,cw

# %%
print angle( rfdata[(mm,mm,0,1)]['A'] * rfdata[(ll,mm,0,1)]['A'].conj() )
print angle( mmrdns.Afit(mm,mm,0,mmrdns.q2eta(q))  * mmrdns.Afit(ll,mm,0,mmrdns.q2eta(q)).conj() )
# Out:
# -0.290288144043
# 0.212005139628

# %%
#
def rawfit(t):
    y = zeros( t.shape, dtype=complex )
    for k,row in enumerate(data):
        #
        ll,mm,q,m1,m2,x1,x2,jf,Mf,qid,rew,imw,rewfit,imwfit,reA,imA,reAmean,imAmean,minA,maxA,T1,dT,match,rmse,reB,imB,reBmean,imBmean,minB,maxB = row
        ll,mm = int(ll),int(mm)
        A = reA+1j*imA
        cw = rew + 1j*imw
        try:
            l,m,n,p = mmrdns.calc_z(qid)
        except:
            l,m,n,p,l2,m2,n2,p2 = mmrdns.calc_z(qid)
        # NOTE that the amplitudes are for Psi4 here
        if True: # (l,m,n,p) in [ (2,2,0,1) ,(2,2,1,1) ]  :
            y += A*exp( 1j*cw*(t-T0) )
            
    #
    a = gwf( array( [t,y.real,-y.imag] ).T )
    
    #
    return a,q

_,q = rawfit( linspace(T0,50) )

#
A = scsearch( keyword='hrq',notkeyword='athena', q=q, nonspinning=True,verbose=True )[0]

#
imrnr = gwylm( A, lm=([ll,mm],[2,2]), verbose=True, dt=0.5 )
nr = imrnr.ringdown(T0=T0)

y,_ = rawfit( nr.lm[(ll,mm)]['psi4'].t )

#
eta = mmrdns.q2eta(q)
h = mmrdns.meval_spherical_mode(ll,mm,eta,kind='psi4',gwfout=True)(nr.ylm[0].t)

h.align(nr.lm[(ll,mm)]['psi4'],method='average-phase',mask=nr.ylm[0].t<60)
y.align(nr.lm[(ll,mm)]['psi4'],method='average-phase',mask=nr.ylm[0].t<60)

nr.lm[(ll,mm)]['psi4'].plot()
y.plot()
h.plot()

fig = figure( figsize=2*array([5,3]) )
gca().set_yscale("log", nonposy='clip')

plot( nr.ylm[0].t, nr.lm[(ll,mm)]['psi4'].amp, color=0.5*ones((3,)), label=None )
plot( nr.ylm[0].t, y.amp, '--k', label=None )
plot( nr.ylm[0].t, h.amp, 'k', alpha=0.2, linewidth=6, label=None )

plot( nr.ylm[0].t, nr.lm[(ll,mm)]['psi4'].plus, color=0.5*ones((3,)), label='NR' )
plot( nr.ylm[0].t, y.plus, '--k', label='RAW-FIT' )
plot( nr.ylm[0].t, h.plus, 'k', alpha=0.2, linewidth=6,label='MMRDNS' )

# plot( nr.ylm[0].t, nr.lm[(ll,mm)]['psi4'].cross, color=0.5*ones((3,)), label='NR', alpha=0.8 )
# plot( nr.ylm[0].t, y.cross, '--k', label='RAW-FIT', alpha=0.8 )
# plot( nr.ylm[0].t, h.cross, 'k', alpha=0.1, linewidth=6, label='MMRDNS' )

ylim( [max(nr.lm[(ll,mm)]['psi4'].amp)*1e-5,1.2*max(nr.lm[(ll,mm)]['psi4'].amp)] )
xlim( [T0,150] )

xlabel(r'$(t-{t^{\mathrm{Peak}}}_{\mathrm{Lum.}})/M$')
ylabel(r'${rM}\psi_{%i%i}$'%(ll,mm))

legend(frameon=False)
title( nr.label )

savefig('mmrdns_psi4_comparison_%s_ll%imm%i.pdf'%(nr.label.replace('-','_'),ll,mm))

# gca().set_yscale("log", nonposy='clip')
# Out:
# [scsearch]>> Found keyword (='hrq') keyword.
# [scsearch]>> Found nonspinning (=True) keyword.
# [scsearch]>> Found notkeyword (='athena') keyword.
# [scsearch]>> Found q (=2.7999984800000002) keyword.
# [scsearch]>> Found verbose (=True) keyword.
# (scsearch)>> List of keywords or string keyword found: ALL scentry objects matching will be passed. To pass ANY entries matching the keywords, input the keywords using an iterable of not of type list.
# ## Found 1 possibly degenerate simulations:
# [0001][numrel-hrqseries] D9_q2.8_a0.0_m160: ns-q2.80
#
# (gwylm)>> Found clean (=False) keyword.
# (gwylm)>> Found dt (=0.5) keyword.
# (gwylm)>> Found lm (=([4, 3], [2, 2])) keyword.
# (gwylm)>> Found load (=True) keyword.
# (gwylm)>> Found scentry_obj (=<nrutils.core.nrsc.scentry instance at 0x10b105368>) keyword.
# (gwylm)>> Found verbose (=True) keyword.
# (load)>> Loading: mp_WeylScal4::Psi4i_l4_m3_r75.00.asc
# (load)>> Re-orienting waveform phase to be consistent with internal sign convention for Psi4, where sign(dPhi/dt)=1*sign(m). Note that the internal sign convention is defined in ... nrutils/core/__init__.py as "M_RELATIVE_SIGN_CONVENTION". This message has appeared becuase the waveform is determioned to obey and sign convention: sign(dPhi/dt)=-1*sign(m).
# (load)>> Loading: mp_WeylScal4::Psi4i_l2_m2_r75.00.asc
# (load)>> Re-orienting waveform phase to be consistent with internal sign convention for Psi4, where sign(dPhi/dt)=1*sign(m). Note that the internal sign convention is defined in ... nrutils/core/__init__.py as "M_RELATIVE_SIGN_CONVENTION". This message has appeared becuase the waveform is determioned to obey and sign convention: sign(dPhi/dt)=-1*sign(m).
# (gwylm)>> Using w22 from a PN estimate to calculate strain multipoles [see pnw0 in basics.py, and/or arxiv:1310.1528v4].
# * w0(w22) = 0.086705 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# * w0(w22) = 0.057803 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calchlm)>> The user should note that there is no minus sign used in front of the double time integral for strain (i.e. Eq 4 of arxiv:1006.1632). This differs from Eq 3.4 of arxiv:0707.4654v3. The net effect is a rotation of the overall polarization of pi degrees. The user should also note that there is no minus sign applied to h_cross meaning that the user must be mindful to write h_pluss-1j*h_cross when appropriate.
# * w0(w22) = 0.086705 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# * w0(w22) = 0.057803 (this is the lower frequency used for FFI method [arxiv:1006.1632v3])
# (gwylm.calcflm!)>> flm, the first integral of Psi4, will not be calculated because it has already been calculated for the current object

# %% [markdown]
# ### NOTES
#
# * Limitting the raw data to only use (2,2,0 or 1) and the model to the same modes results in correct amplitudes:
#     1. comparing amplitudes individual yields good agreement between raw data and (raw)fit
#     2. comparing sum of amplitudes yeilds disagreement between raw data and (raw)fit
#     3. _Conclusion_: the phases are being handled incorrectly by python implementation of mmrdns
# * Correction of phases:
#     1. It has been found that the (2,2,1) mode should have its amplitude multiplied by -1 in order to reproducte the correct behavior. This is identical to a phase shift of $\pm\pi$.
#     2. This most likely results from the approximation used for the kick velocity:
#         $$\phi_{\mathrm{kick}}(t) \approx \frac{1}{2}\phi_{220}(t) $$
#     3. In the equation above, $\phi_{220}$ has a $2\pi$ shift ambiguity, meaning that $\phi_{220}/2$ has a $\pi$ shift ambiguity.
#         $$\phi_{\mathrm{kick}}(t) \approx \frac{1}{2}\phi_{220}(t) \pm \pi $$
#     4. This total ambiguity may be fixed by using the (2,1,0) qnm as a reference rather than (2,2,0):
#         $$\phi_{\mathrm{kick}}(t) \approx_{???} \phi_{210}(t) \pm 0 $$
#
# * For some reason the $(l,m,n)=(3,2,0)$ fit amplitude is the conjugate of what it needs to be!
#
# ### BURNING QUESTIONS
# * Does MMRDNS recover the correct relative phases for all 9 modes? How can this be tested? ---> Tested. At first it didnt, but now it does.
# * What are the simple demonstrative plots that can be make? ---> It depends on the purpose. More thought needed.
# * Can relative phase alignment be done with the $(2,1)$ NR spherical harmonic? ---> Likley possible, but not necessary.
#
# ### ACTION ITEMS
# 1. Write notebook to compare relative phases for all modes modeled by MMRDNS
# 2. Try calibration of QNM amplitude phases using $(l,m,n)=(2,1,0)$ mode as a reference for the kick phase
# 3. The example above demonstrates that adding modes $(3,2,1)$ and $(3,2,2)$ may generally result in close agreement with NR closer to the peak:
#     * Determine whether these modes have sufficient data to be modeled.
#     * Try to model these modes and implement said models into MMRDNS.

# %%
nr.simdir
# Out:
# '/Users/book/MOUNT/datafiles@gatech/Waveforms/HRq-series/D9_q1.2_a0.0_m160/'
